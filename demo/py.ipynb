# %% [markdown]
# # 变量

# %%
a=1+1
a
# Out:
# 2

# %%
s_1="day"
s_2="one"
s_3=f"two {s_1} {s_2}"
s_3
# str int float bool
# Out:
# 'two day one'

# %% [markdown]
# # 元组

# %%
(1,2,3)
a,b,c=1,1,2
a,b=1,2
a,b=b,a
value=1,2,3,4,5
a,b,*c=value
c
# Out:
# [3, 4, 5]

# %% [markdown]
# # 函数

# %%
str.__doc__

def my_fun(v):
    '''我的函数'''
    return v+1
my_fun(1)
# Out:
# 2

# %% [markdown]
# # 类

# %%
class Counter:
    '''计数器'''
    def __init__(self, start=0):
        self.value = start

    def inc(self):
        self.value += 1
        return self.value
counter = Counter()
counter.inc()
# Out:
# 1
